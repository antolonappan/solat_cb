# %%
import matplotlib.pyplot as plt
import healpy as hp
import numpy as np
import sys
import os
sys.path.append('..')

# %%
# %load_ext autoreload
# %autoreload 2
from solat_cb.simulation import NoiseSpectra

# %%
lmax = 4000
sensitivity_mode = 2
atm_noise = True
fsky = 0.6

# %%
NellLat = NoiseSpectra(sensitivity_mode, fsky,lmax,atm_noise,"LAT")

# %%
plt.figure(figsize=(10,3))
freq = list(NellLat.keys())[1:]
for i in range(3):
    plt.subplot(131+i)
    for j in range(3):
        freq_i = i*3+j
        plt.loglog(NellLat[freq[freq_i]], label=freq[freq_i])
        plt.legend()

# %%
NellSat = NoiseSpectra(sensitivity_mode, fsky,lmax,atm_noise,"SAT")

# %%
plt.figure(figsize=(10,3))
freq = list(NellSat.keys())[1:]
for i in range(3):
    plt.subplot(131+i)
    for j in range(3):
        freq_i = i*3+j
        plt.loglog(NellSat[freq[freq_i]], label=freq[freq_i])
        plt.legend()
