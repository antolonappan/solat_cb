# %%
import matplotlib.pyplot as plt
import healpy as hp
import numpy as np
import sys
import os
sys.path.append('..')

# %%
# %load_ext autoreload
# %autoreload 2
from lat_cb.signal import CMB, Foreground, Noise, LATsky, SO_LAT_Nell

# %%
lib = '/pscratch/sd/l/lonappan/SOLAT'

# %%
sm = 2
fsky = 0.4
lmax = 3071

# %%
Noise(512,atm_noise=True,atm_corr=False).noiseQU(plot=True)

# %%
Noise(512,atm_noise=True,atm_corr=True).noiseQU(plot=True)
